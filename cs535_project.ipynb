# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.layers import Dropout
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import seaborn as sns

# %%
data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,  # Random rotations
    width_shift_range=0.1,  # Random horizontal shifts
    height_shift_range=0.1,  # Random vertical shifts
    shear_range=0.1,  # Shear transformations
    zoom_range=0.1,  # Random zoom
    horizontal_flip=True,  # Random horizontal flips
    fill_mode='nearest',
    validation_split=0.2
)


train_data = data_gen.flow_from_directory(
    'C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\train',
    target_size=(224, 224),  # ResNet-50 expects 224x224 images
    batch_size=16,
    class_mode='binary',
    color_mode='rgb',  # Convert grayscale to 3 channels
    subset='training'
)

val_data = data_gen.flow_from_directory(
    'C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\train',
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary',
    color_mode='rgb',
    subset='validation'
)

test_data = data_gen.flow_from_directory(
    'C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\test',
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary',
    color_mode='rgb',
    shuffle=False
)
# Out:
# Found 6400 images belonging to 2 classes.
# Found 1600 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=Input(shape=(224, 224, 3)))
base_model.trainable = False  # Freeze the base model

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)  # Use dropout to add regularization
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cb = ModelCheckpoint('C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\best_cs_535_model.h5', save_best_only=True)

# Add this before model.fit()
model_checkpoint_callback = ModelCheckpoint(
    filepath='C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\best_cs_535_model.h5',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_learning_rate = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_learning_rate=0.0001,
    verbose=1
)

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=50,
    callbacks=[model_checkpoint_callback, reduce_learning_rate]
)

model.save('C:\\Users\\sarow\\OneDrive\\Desktop\\CS535_Project\\final_cs_535_resnet_model.h5')



# Then add 'model_checkpoint_callback' to the callbacks list in model.fit()
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 400/400 [==============================] - ETA: 0s - loss: 0.6316 - accuracy: 0.6522
# Epoch 1: val_loss improved from inf to 0.49804, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# C:\Users\sarow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 400/400 [==============================] - 573s 1s/step - loss: 0.6316 - accuracy: 0.6522 - val_loss: 0.4980 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 2/50
# 400/400 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.7278
# Epoch 2: val_loss did not improve from 0.49804
# 400/400 [==============================] - 490s 1s/step - loss: 0.5367 - accuracy: 0.7278 - val_loss: 0.5182 - val_accuracy: 0.7337 - lr: 0.0010
# Epoch 3/50
# 400/400 [==============================] - ETA: 0s - loss: 0.5046 - accuracy: 0.7598
# Epoch 3: val_loss improved from 0.49804 to 0.44200, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 488s 1s/step - loss: 0.5046 - accuracy: 0.7598 - val_loss: 0.4420 - val_accuracy: 0.8100 - lr: 0.0010
# Epoch 4/50
# 400/400 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.7528
# Epoch 4: val_loss did not improve from 0.44200
# 400/400 [==============================] - 526s 1s/step - loss: 0.5063 - accuracy: 0.7528 - val_loss: 0.4762 - val_accuracy: 0.7725 - lr: 0.0010
# Epoch 5/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.7766
# Epoch 5: val_loss improved from 0.44200 to 0.44083, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 499s 1s/step - loss: 0.4809 - accuracy: 0.7766 - val_loss: 0.4408 - val_accuracy: 0.8250 - lr: 0.0010
# Epoch 6/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.7798
# Epoch 6: val_loss improved from 0.44083 to 0.42036, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 500s 1s/step - loss: 0.4687 - accuracy: 0.7798 - val_loss: 0.4204 - val_accuracy: 0.8119 - lr: 0.0010
# Epoch 7/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4743 - accuracy: 0.7794
# Epoch 7: val_loss did not improve from 0.42036
# 400/400 [==============================] - 500s 1s/step - loss: 0.4743 - accuracy: 0.7794 - val_loss: 0.4307 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 8/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.7880
# Epoch 8: val_loss did not improve from 0.42036
# 400/400 [==============================] - 495s 1s/step - loss: 0.4585 - accuracy: 0.7880 - val_loss: 0.4306 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 9/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7987
# Epoch 9: val_loss did not improve from 0.42036
# 400/400 [==============================] - 494s 1s/step - loss: 0.4500 - accuracy: 0.7987 - val_loss: 0.4308 - val_accuracy: 0.7937 - lr: 0.0010
# Epoch 10/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.8008
# Epoch 10: val_loss improved from 0.42036 to 0.38405, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 495s 1s/step - loss: 0.4451 - accuracy: 0.8008 - val_loss: 0.3841 - val_accuracy: 0.8381 - lr: 0.0010
# Epoch 11/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4389 - accuracy: 0.7997
# Epoch 11: val_loss did not improve from 0.38405
# 400/400 [==============================] - 501s 1s/step - loss: 0.4389 - accuracy: 0.7997 - val_loss: 0.3975 - val_accuracy: 0.8369 - lr: 0.0010
# Epoch 12/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.8053
# Epoch 12: val_loss did not improve from 0.38405
# 400/400 [==============================] - 513s 1s/step - loss: 0.4318 - accuracy: 0.8053 - val_loss: 0.4260 - val_accuracy: 0.8012 - lr: 0.0010
# Epoch 13/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4331 - accuracy: 0.8034
# Epoch 13: val_loss improved from 0.38405 to 0.38298, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 496s 1s/step - loss: 0.4331 - accuracy: 0.8034 - val_loss: 0.3830 - val_accuracy: 0.8381 - lr: 0.0010
# Epoch 14/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8138
# Epoch 14: val_loss did not improve from 0.38298
# 400/400 [==============================] - 495s 1s/step - loss: 0.4251 - accuracy: 0.8138 - val_loss: 0.3867 - val_accuracy: 0.8294 - lr: 0.0010
# Epoch 15/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4362 - accuracy: 0.8028
# Epoch 15: val_loss improved from 0.38298 to 0.36794, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 494s 1s/step - loss: 0.4362 - accuracy: 0.8028 - val_loss: 0.3679 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 16/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8097
# Epoch 16: val_loss did not improve from 0.36794
# 400/400 [==============================] - 494s 1s/step - loss: 0.4237 - accuracy: 0.8097 - val_loss: 0.3747 - val_accuracy: 0.8506 - lr: 0.0010
# Epoch 17/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.8216
# Epoch 17: val_loss improved from 0.36794 to 0.36158, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 493s 1s/step - loss: 0.4092 - accuracy: 0.8216 - val_loss: 0.3616 - val_accuracy: 0.8481 - lr: 0.0010
# Epoch 18/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8138
# Epoch 18: val_loss did not improve from 0.36158
# 400/400 [==============================] - 494s 1s/step - loss: 0.4205 - accuracy: 0.8138 - val_loss: 0.3783 - val_accuracy: 0.8331 - lr: 0.0010
# Epoch 19/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8122
# Epoch 19: val_loss did not improve from 0.36158
# 400/400 [==============================] - 492s 1s/step - loss: 0.4202 - accuracy: 0.8122 - val_loss: 0.3664 - val_accuracy: 0.8381 - lr: 0.0010
# Epoch 20/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8177
# Epoch 20: val_loss improved from 0.36158 to 0.36027, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 493s 1s/step - loss: 0.4180 - accuracy: 0.8177 - val_loss: 0.3603 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 21/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4118 - accuracy: 0.8180
# Epoch 21: val_loss improved from 0.36027 to 0.35333, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 497s 1s/step - loss: 0.4118 - accuracy: 0.8180 - val_loss: 0.3533 - val_accuracy: 0.8581 - lr: 0.0010
# Epoch 22/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4106 - accuracy: 0.8234
# Epoch 22: val_loss improved from 0.35333 to 0.34753, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 496s 1s/step - loss: 0.4106 - accuracy: 0.8234 - val_loss: 0.3475 - val_accuracy: 0.8581 - lr: 0.0010
# Epoch 23/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4106 - accuracy: 0.8242
# Epoch 23: val_loss did not improve from 0.34753
# 400/400 [==============================] - 496s 1s/step - loss: 0.4106 - accuracy: 0.8242 - val_loss: 0.3796 - val_accuracy: 0.8475 - lr: 0.0010
# Epoch 24/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4004 - accuracy: 0.8231
# Epoch 24: val_loss did not improve from 0.34753
# 400/400 [==============================] - 494s 1s/step - loss: 0.4004 - accuracy: 0.8231 - val_loss: 0.3696 - val_accuracy: 0.8331 - lr: 0.0010
# Epoch 25/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8248
# Epoch 25: val_loss did not improve from 0.34753
# 400/400 [==============================] - 492s 1s/step - loss: 0.4015 - accuracy: 0.8248 - val_loss: 0.3510 - val_accuracy: 0.8550 - lr: 0.0010
# Epoch 26/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.8153
# Epoch 26: val_loss improved from 0.34753 to 0.33186, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 539s 1s/step - loss: 0.4114 - accuracy: 0.8153 - val_loss: 0.3319 - val_accuracy: 0.8644 - lr: 0.0010
# Epoch 27/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.8267
# Epoch 27: val_loss did not improve from 0.33186
# 400/400 [==============================] - 490s 1s/step - loss: 0.3929 - accuracy: 0.8267 - val_loss: 0.3645 - val_accuracy: 0.8350 - lr: 0.0010
# Epoch 28/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8209
# Epoch 28: val_loss did not improve from 0.33186
# 400/400 [==============================] - 492s 1s/step - loss: 0.4046 - accuracy: 0.8209 - val_loss: 0.3562 - val_accuracy: 0.8481 - lr: 0.0010
# Epoch 29/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8336
# Epoch 29: val_loss did not improve from 0.33186
# 400/400 [==============================] - 500s 1s/step - loss: 0.3834 - accuracy: 0.8336 - val_loss: 0.3363 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 30/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8255
# Epoch 30: val_loss improved from 0.33186 to 0.32674, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 495s 1s/step - loss: 0.3884 - accuracy: 0.8255 - val_loss: 0.3267 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 31/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8256
# Epoch 31: val_loss did not improve from 0.32674
# 400/400 [==============================] - 494s 1s/step - loss: 0.4053 - accuracy: 0.8256 - val_loss: 0.3355 - val_accuracy: 0.8644 - lr: 0.0010
# Epoch 32/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4043 - accuracy: 0.8200
# Epoch 32: val_loss did not improve from 0.32674
# 400/400 [==============================] - 490s 1s/step - loss: 0.4043 - accuracy: 0.8200 - val_loss: 0.3676 - val_accuracy: 0.8475 - lr: 0.0010
# Epoch 33/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3975 - accuracy: 0.8305
# Epoch 33: val_loss did not improve from 0.32674
# 400/400 [==============================] - 498s 1s/step - loss: 0.3975 - accuracy: 0.8305 - val_loss: 0.3600 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 34/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3946 - accuracy: 0.8231
# Epoch 34: val_loss improved from 0.32674 to 0.32446, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 502s 1s/step - loss: 0.3946 - accuracy: 0.8231 - val_loss: 0.3245 - val_accuracy: 0.8625 - lr: 0.0010
# Epoch 35/50
# 400/400 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.8227
# Epoch 35: val_loss did not improve from 0.32446
# 400/400 [==============================] - 32841s 82s/step - loss: 0.4068 - accuracy: 0.8227 - val_loss: 0.3363 - val_accuracy: 0.8600 - lr: 0.0010
# Epoch 36/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8366
# Epoch 36: val_loss improved from 0.32446 to 0.31952, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 312s 779ms/step - loss: 0.3882 - accuracy: 0.8366 - val_loss: 0.3195 - val_accuracy: 0.8656 - lr: 0.0010
# Epoch 37/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8319
# Epoch 37: val_loss did not improve from 0.31952
# 400/400 [==============================] - 328s 821ms/step - loss: 0.3903 - accuracy: 0.8319 - val_loss: 0.3337 - val_accuracy: 0.8662 - lr: 0.0010
# Epoch 38/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.8278
# Epoch 38: val_loss did not improve from 0.31952
# 400/400 [==============================] - 363s 906ms/step - loss: 0.3980 - accuracy: 0.8278 - val_loss: 0.3613 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 39/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.8358
# Epoch 39: val_loss did not improve from 0.31952
# 400/400 [==============================] - 423s 1s/step - loss: 0.3943 - accuracy: 0.8358 - val_loss: 0.3362 - val_accuracy: 0.8675 - lr: 0.0010
# Epoch 40/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8297
# Epoch 40: val_loss did not improve from 0.31952
# 400/400 [==============================] - 318s 794ms/step - loss: 0.3989 - accuracy: 0.8297 - val_loss: 0.3432 - val_accuracy: 0.8469 - lr: 0.0010
# Epoch 41/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3919 - accuracy: 0.8273
# Epoch 41: val_loss did not improve from 0.31952
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 400/400 [==============================] - 321s 802ms/step - loss: 0.3919 - accuracy: 0.8273 - val_loss: 0.3291 - val_accuracy: 0.8631 - lr: 0.0010
# Epoch 42/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8464
# Epoch 42: val_loss did not improve from 0.31952
# 400/400 [==============================] - 327s 817ms/step - loss: 0.3583 - accuracy: 0.8464 - val_loss: 0.3333 - val_accuracy: 0.8631 - lr: 2.0000e-04
# Epoch 43/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8473
# Epoch 43: val_loss did not improve from 0.31952
# 400/400 [==============================] - 337s 841ms/step - loss: 0.3666 - accuracy: 0.8473 - val_loss: 0.3241 - val_accuracy: 0.8587 - lr: 2.0000e-04
# Epoch 44/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8519
# Epoch 44: val_loss did not improve from 0.31952
# 400/400 [==============================] - 312s 780ms/step - loss: 0.3493 - accuracy: 0.8519 - val_loss: 0.3263 - val_accuracy: 0.8562 - lr: 2.0000e-04
# Epoch 45/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8503
# Epoch 45: val_loss improved from 0.31952 to 0.31475, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 313s 781ms/step - loss: 0.3497 - accuracy: 0.8503 - val_loss: 0.3148 - val_accuracy: 0.8656 - lr: 2.0000e-04
# Epoch 46/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8534
# Epoch 46: val_loss improved from 0.31475 to 0.30971, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 321s 801ms/step - loss: 0.3540 - accuracy: 0.8534 - val_loss: 0.3097 - val_accuracy: 0.8706 - lr: 2.0000e-04
# Epoch 47/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8520
# Epoch 47: val_loss did not improve from 0.30971
# 400/400 [==============================] - 316s 790ms/step - loss: 0.3499 - accuracy: 0.8520 - val_loss: 0.3144 - val_accuracy: 0.8644 - lr: 2.0000e-04
# Epoch 48/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8502
# Epoch 48: val_loss did not improve from 0.30971
# 400/400 [==============================] - 306s 763ms/step - loss: 0.3537 - accuracy: 0.8502 - val_loss: 0.3236 - val_accuracy: 0.8662 - lr: 2.0000e-04
# Epoch 49/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8558
# Epoch 49: val_loss improved from 0.30971 to 0.30139, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 296s 740ms/step - loss: 0.3459 - accuracy: 0.8558 - val_loss: 0.3014 - val_accuracy: 0.8650 - lr: 2.0000e-04
# Epoch 50/50
# 400/400 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8558
# Epoch 50: val_loss improved from 0.30139 to 0.30041, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 283s 707ms/step - loss: 0.3462 - accuracy: 0.8558 - val_loss: 0.3004 - val_accuracy: 0.8669 - lr: 2.0000e-04

# %%
# Unfreeze some of the base model layers
base_model.trainable = True
fine_tune_at = 100  # This is the number of layers from the top to fine-tune

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Compile the model with a low learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

# Continue training
history_fine = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25,  # Continue for more epochs
    callbacks=[model_checkpoint_callback, reduce_learning_rate]
)
# Out:
# Epoch 1/25
# 400/400 [==============================] - ETA: 0s - loss: 17.9110 - accuracy: 0.7148
# Epoch 1: val_loss did not improve from 0.30041
# 400/400 [==============================] - 472s 1s/step - loss: 17.9110 - accuracy: 0.7148 - val_loss: 0.7343 - val_accuracy: 0.8181 - lr: 1.0000e-05
# Epoch 2/25
# 400/400 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.7670
# Epoch 2: val_loss did not improve from 0.30041
# 400/400 [==============================] - 460s 1s/step - loss: 0.6468 - accuracy: 0.7670 - val_loss: 0.4468 - val_accuracy: 0.8425 - lr: 1.0000e-05
# Epoch 3/25
# 400/400 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.7947
# Epoch 3: val_loss did not improve from 0.30041
# 400/400 [==============================] - 461s 1s/step - loss: 0.4684 - accuracy: 0.7947 - val_loss: 0.4630 - val_accuracy: 0.8213 - lr: 1.0000e-05
# Epoch 4/25
# 400/400 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8141
# Epoch 4: val_loss did not improve from 0.30041
# 400/400 [==============================] - 460s 1s/step - loss: 0.4237 - accuracy: 0.8141 - val_loss: 0.3406 - val_accuracy: 0.8619 - lr: 1.0000e-05
# Epoch 5/25
# 400/400 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8284
# Epoch 5: val_loss did not improve from 0.30041
# 400/400 [==============================] - 462s 1s/step - loss: 0.3940 - accuracy: 0.8284 - val_loss: 0.3759 - val_accuracy: 0.8556 - lr: 1.0000e-05
# Epoch 6/25
# 400/400 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8452
# Epoch 6: val_loss improved from 0.30041 to 0.27915, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 463s 1s/step - loss: 0.3627 - accuracy: 0.8452 - val_loss: 0.2791 - val_accuracy: 0.8925 - lr: 1.0000e-05
# Epoch 7/25
# 400/400 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8442
# Epoch 7: val_loss did not improve from 0.27915
# 400/400 [==============================] - 465s 1s/step - loss: 0.3627 - accuracy: 0.8442 - val_loss: 0.3050 - val_accuracy: 0.8581 - lr: 1.0000e-05
# Epoch 8/25
# 400/400 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.8603
# Epoch 8: val_loss did not improve from 0.27915
# 400/400 [==============================] - 463s 1s/step - loss: 0.3219 - accuracy: 0.8603 - val_loss: 0.3158 - val_accuracy: 0.8869 - lr: 1.0000e-05
# Epoch 9/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8731
# Epoch 9: val_loss did not improve from 0.27915
# 400/400 [==============================] - 464s 1s/step - loss: 0.2989 - accuracy: 0.8731 - val_loss: 0.5134 - val_accuracy: 0.8388 - lr: 1.0000e-05
# Epoch 10/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.8753
# Epoch 10: val_loss improved from 0.27915 to 0.24392, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 464s 1s/step - loss: 0.2916 - accuracy: 0.8753 - val_loss: 0.2439 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 11/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8831
# Epoch 11: val_loss improved from 0.24392 to 0.21073, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 462s 1s/step - loss: 0.2883 - accuracy: 0.8831 - val_loss: 0.2107 - val_accuracy: 0.9106 - lr: 1.0000e-05
# Epoch 12/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.8794
# Epoch 12: val_loss did not improve from 0.21073
# 400/400 [==============================] - 461s 1s/step - loss: 0.2929 - accuracy: 0.8794 - val_loss: 0.2396 - val_accuracy: 0.9112 - lr: 1.0000e-05
# Epoch 13/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.8947
# Epoch 13: val_loss did not improve from 0.21073
# 400/400 [==============================] - 462s 1s/step - loss: 0.2681 - accuracy: 0.8947 - val_loss: 0.2277 - val_accuracy: 0.9125 - lr: 1.0000e-05
# Epoch 14/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.8952
# Epoch 14: val_loss did not improve from 0.21073
# 400/400 [==============================] - 464s 1s/step - loss: 0.2570 - accuracy: 0.8952 - val_loss: 0.2433 - val_accuracy: 0.9056 - lr: 1.0000e-05
# Epoch 15/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.8973
# Epoch 15: val_loss did not improve from 0.21073
# 400/400 [==============================] - 465s 1s/step - loss: 0.2446 - accuracy: 0.8973 - val_loss: 0.2371 - val_accuracy: 0.9212 - lr: 1.0000e-05
# Epoch 16/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9100
# Epoch 16: val_loss improved from 0.21073 to 0.16905, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 465s 1s/step - loss: 0.2324 - accuracy: 0.9100 - val_loss: 0.1690 - val_accuracy: 0.9312 - lr: 1.0000e-05
# Epoch 17/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2141 - accuracy: 0.9156
# Epoch 17: val_loss did not improve from 0.16905
# 400/400 [==============================] - 466s 1s/step - loss: 0.2141 - accuracy: 0.9156 - val_loss: 0.2425 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 18/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9197
# Epoch 18: val_loss did not improve from 0.16905
# 400/400 [==============================] - 464s 1s/step - loss: 0.2008 - accuracy: 0.9197 - val_loss: 0.2135 - val_accuracy: 0.9175 - lr: 1.0000e-05
# Epoch 19/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9212
# Epoch 19: val_loss did not improve from 0.16905
# 400/400 [==============================] - 486s 1s/step - loss: 0.2077 - accuracy: 0.9212 - val_loss: 0.1878 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 20/25
# 400/400 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9261
# Epoch 20: val_loss did not improve from 0.16905
# 400/400 [==============================] - 464s 1s/step - loss: 0.1843 - accuracy: 0.9261 - val_loss: 0.2305 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 21/25
# 400/400 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9222
# Epoch 21: val_loss did not improve from 0.16905
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 400/400 [==============================] - 462s 1s/step - loss: 0.2000 - accuracy: 0.9222 - val_loss: 0.2271 - val_accuracy: 0.9206 - lr: 1.0000e-05
# Epoch 22/25
# 400/400 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9416
# Epoch 22: val_loss improved from 0.16905 to 0.13331, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 464s 1s/step - loss: 0.1436 - accuracy: 0.9416 - val_loss: 0.1333 - val_accuracy: 0.9563 - lr: 2.0000e-06
# Epoch 23/25
# 400/400 [==============================] - ETA: 0s - loss: 0.1460 - accuracy: 0.9433
# Epoch 23: val_loss improved from 0.13331 to 0.11877, saving model to C:\Users\sarow\OneDrive\Desktop\CS535_Project\best_cs_535_model.h5
# 400/400 [==============================] - 465s 1s/step - loss: 0.1460 - accuracy: 0.9433 - val_loss: 0.1188 - val_accuracy: 0.9531 - lr: 2.0000e-06
# Epoch 24/25
# 400/400 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9466
# Epoch 24: val_loss did not improve from 0.11877
# 400/400 [==============================] - 466s 1s/step - loss: 0.1341 - accuracy: 0.9466 - val_loss: 0.1629 - val_accuracy: 0.9438 - lr: 2.0000e-06
# Epoch 25/25
# 400/400 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9472
# Epoch 25: val_loss did not improve from 0.11877
# 400/400 [==============================] - 464s 1s/step - loss: 0.1333 - accuracy: 0.9472 - val_loss: 0.1287 - val_accuracy: 0.9475 - lr: 2.0000e-06

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_data)
print(f'Test accuracy: {test_acc:.4f}, Test loss: {test_loss:.4f}')

# Predict on the test set
predictions = (model.predict(test_data) > 0.5).astype(int).flatten()

# True labels
true_labels = test_data.classes

# Detailed metrics
conf_matrix = confusion_matrix(true_labels, predictions)
precision = precision_score(true_labels, predictions)
recall = recall_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions)
accuracy = accuracy_score(true_labels, predictions)

print(f'Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}, Accuracy: {accuracy:.4f}')
# Out:
# 125/125 [==============================] - 81s 644ms/step - loss: 0.1462 - accuracy: 0.9445
# Test accuracy: 0.9445, Test loss: 0.1462
# 125/125 [==============================] - 70s 553ms/step
# Precision: 0.9786, Recall: 0.9160, F1 Score: 0.9463, Accuracy: 0.9480

# %%
# Confusion Matrix
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Training History
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

plt.show()
